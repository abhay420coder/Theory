# %% [markdown]
# # function
#
# * A function is a "subprogram" that can be called by code external (or internal, in the case of recursion) to the function.
# * Like the program itself, a function is composed of a sequence of statements called the function body.
# * Values can be passed to a function as parameters, and the function will return a value.
# * A function is simply a “chunk” of code that you can use over and over again, rather than writing it out multiple times.
# * Functions enable programmers to break down or decompose a problem into smaller chunks, each of which performs a particular task.

# %% [markdown]
# ## Argument vs Parameter
#
# * A parameter is a named variable passed into a function.
# * Parameter variables are used to import arguments into functions.
# * Function parameters are the names listed in the function's definition.
# * Function arguments are the real values passed to the function.
# * Parameters are initialized to the values of the arguments supplied.
#
# * A parameter is one of the variables in a function.
#     * And when a method is called, the arguments are the data you pass into the method's parameters.

# %% [markdown]
# # Types of Function :- JavaScript
#
# > * `return` keyword **stops the execution of a function** and **returns the desired output**.
# > * in javascript a function should be called with the **correct number of arguments**.
# >   * if you are not calling with correct number of argunments
# >     * then which argunment will not call that will take `NaN` as default value.
# >   * if you are calling with correct number of argunments
# >     * then you get desired value.

# %% [markdown]
# ### Normal/Regular    Function ....
#
# #### General Syntax   :-
#
# ```js
# function functionName(para1=defVal1 , para2=defVal2, ..... , paraN=defValN  ){
# 	// function  statement(s)
# }
# ```
#
# > * defVal = default value :- it is totally optional.
# > * or  if you are not sending any default value then
# > 	* 	that will take `NaN`
# > 	*	otherwise during `calling function` , whatever you will send data that will take.
#
#
# ```js
# function functionName(para1 , para2, ..... , paraN){
# 	// function  statement(s)
# }
# ```
#
# #### call Regular function
#
# `functionName (arg1, arg2, ..... , argN)`

# %% [markdown]
# ### Function Expression ....
#
# #### General Syntax   :-
#
# ```js
# var/let/const variableName = function functionName(para1=defval1 , para2=defval2, ..... , paraN=defvalN  ){
# 	//  function statement(s)
# }
# ```
#
# > or
#
# ```js
# var/let/const variableName = function functionName(para1 , para2, ..... , paraN  ){
# 	//  function statement(s)
# }
# ```
#
# > or
#
# ```js
# var/let/const  variableName = function Structure
# ```
#
# #### call Function Expression
#
# `variableName(arg0, arg2, ..... , argN)`

# %% [markdown]
# ### Anonymus Function ....
#
# #### General Syntax :-
#
# ```js
# var/let/const  functionName = function (para1=defval1 , para2=defval2, ..... , paraN=defvalN   ){
# 	//  function statement(s)
# }
# ```
#
# > or
#
# ```js
# var/let/const  functionName = function (para1 , para2, ..... , paraN  ){
# 	//  function statement(s)
# }
# ```
#
# #### call Anonymus Function
#
# `functionName (arg0, arg2, ..... , argN)`

# %% [markdown]
# ### Arrow Function :-  JAvaScript ....
#
# * which arrow function is use to reduce number of lines of the code & is use to avoid `this` keyword conflict.
# * Arrow function allows us to increase a efficiency of a pogram and allows us to create cleaner syntax.

# %% [markdown]
# #### Rule :-
#
# * Whenever we use arrow function then
#   * the `function` keyword shold not be used.
# * when we use arrow function are not manadatory
#   * if the function is having only one statement.
# * if the one statement is `return` statement
#   * then `return` keyword should not be used.
# * if the function is accepting only one argunment
#   * then parenthesis `()` is not manadatory.
#   * parenthesis :- () :- small bracket.
# * if the function is having
#   * 0 (zero) argunment or more then one argunment
#   * then parenthesis is manadatory.
# * if the function having more than one statement
#   * curly bracket is manadatory and `return` keyword are also manadatory.
# * **note :-** we can convert an anonumous function not named fumctions

# %% [markdown]
# #### General Syntax   :-

# %% [markdown]
# ##### for more than one statement
#
# > If Arrow Function has More Than One Parameter and More Than One Statement   :-
#
# ```js
# var/let/const functionName = (para1=defval1 , para2=defval2, ..... , paraN=defvalN ) => {
# 	//  function statement(s)
# }
# ```
# **or**
#
# ```js
# var/let/const functionName = (para1 , para2, ..... , paraN  ) => {
# 	//  function statement(s)
# }
# ```
#
# > If Arrow Function has Zero Parameter and More Than One Statement   :-
#
# ```js
# var/let/const functionName = () => {
# 	//  function statement(s)
# }
# ```
#
# > If Arrow Function has One Parameter and More Than One Statement   :-
#
# ```js
# var/let/const functionName =  (para1=defval1)=> {
# 	//  function statement(s)
# }
# ```
#
# **or**
#
# ```js
# var/let/const functionName =  (para1)=> {
# 	//  function statement(s)
# }
# ```
#
# **or**
#
# ```js
# var/let functionName = para1  => {
# 	//  function statement(s)
# }
# ```

# %% [markdown]
# ##### For Single Statement
#
# > if function has  one statement that is return statement then return keyword should not be used
#
# > If Arrow Function has More Than One Parameter and Single Statement   :-
#
# ```js
# var/let functionName= (para1=defval1 , para2=defval2, ..... , paraN=defvalN) => //  function Statement
# ```
#
# **or**
#
# ```js
# var/let functionName= (para1 , para2, ..... , paraN  ) => //  function Statement
# ```
#
# > If Arrow Function has Zero Parameter and Single  Statement   :-
#
# ```js
# var/let functionName = () =>  //  function Statement
# ```
#
# > If Arrow Function has One Parameter and Single Statement   :-
#
# ```js
# var/let functionName = (para1=defVal1)  => 	//  function Statement
# ```
#
# **or**
#
# ```js
# var/let functionName = (para1)  => 	//  function Statement
# ```
#
# **or**
#
# ```js
# var/let functionName = para1 => //  function Statement
# ```

# %% [markdown]
# #### call  Arrow Function
#
# `functionName (arg0, arg2, ..... , argN)`

# %% [markdown]
# ### call function
#
# > **Note :-**
# >   * in javascript a function should be called with the **correct number of arguments**.
# >     * number of parameters = number of arguments
# >   * if you are not calling with correct number of argunments
# >     * then which argunment will not call that will take `NaN` as default value.
# >   * if you are calling with correct number of argunments
# >     * then you get desired value.
#
#
# > Regular function  /  Anonymus Function    /   Arrow Function
#
# `functionName (arg1, arg2, ..... , argN)`
#
# > Function Expression
#
# `variableName(arg0, arg2, ..... , argN)`

# %% [markdown]
# ### Convert Regular Function to Anonymus Function to Arrow Function
#
# > Regular Function
#
# ```js
# function functionName  (para1=defval1 , para2=defval2, ..... , paraN=defvalN  ){
# 	// function  statement(s)
# }
# ```
#
# > Anonymus Function
#
# ```js
# var/let/const  functionName = function (para1=defval1 , para2=defval2, ..... , paraN=defvalN   ){
# 	//  function statement(s)
# }
# ```
#
# > Arrow function
#
# ```js
# var/let/const functionName = (para1=defval1 , para2=defval2, ..... , paraN=defvalN ) => {
# 	//  function statement(s)
# }
# ```
#
#
# ##### or
#
# > Regular Function
#
# ```js
# function functionName(para1 , para2, ..... , paraN){
# 	// function  statement(s)
# }
# ```
#
# > Anonymus Function
#
# ```js
# var/let/const  functionName = function (para1 , para2, ..... , paraN  ){
# 	//  function statement(s)
# }
# ```
#
# > Arrow function
#
# ```js
# var/let/const functionName = (para1 , para2, ..... , paraN  ) => {
# 	//  function statement(s)
# }
# ```

# %% [markdown]
# ### Asynchronous Programming
# * Functions running in parallel with other functions are called asynchronous
#
# * With asynchronous programming,
#     * JavaScript programs can start long-running tasks,
#     * and continue running other tasks in parallell.
# * But, asynchronus programmes are difficult to write and difficult to debug.
#
# * Because of this, most modern asynchronous JavaScript methods don't use callbacks.
#     * Instead, in JavaScript, asynchronous programming is solved using Promises instead.
# * The term asynchronous refers to two or more objects or events
#   * not existing or happening at the same time
#   * (or multiple related things happening without waiting for the previous one to complete).
#   * In computing, the word "asynchronous" is used in two major contexts.
# * content
#   * callBack function
#   * promises
#   * Async/Await

# %% [markdown]
# ### Synchronous VS Asynchronous
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Call Back Function
#
# * A callback function is a function passed into another function as an argument,
#   * which is then invoked inside the outer function to complete some kind of routine or action.
# * A callback is a function passed as an argument to another function
# * This technique allows a function to call another function
# * A callback function can run after another function has finished
#
# > Regular Function
#
# ```js
# function functionName(para1 , para2, ..... , paraN , callBackFunction1, callBackFunction2, ....., callBackFunctionN){
# 	// function  statement(s)
#   callBackFunction1(para1 , para2, ..... , paraN)
#   callBackFunction2(para1 , para2, ..... , paraN)
#     ....................................
#   callBackFunctionN(para1 , para2, ..... , paraN)
# }
# ```
#
# > Anonymus Function
#
# ```js
# var/let/const  functionName = function (para1, para2, ....., paraN, callBackFunction1, callBackFunction2, ....., callBackFunctionN ){
# 	//  function statement(s)
#     callBackFunction1(para1 , para2, ..... , paraN)
#     callBackFunction2(para1 , para2, ..... , paraN)
#       ....................................
#     callBackFunctionN(para1 , para2, ..... , paraN)
# }
# ```
#
# > Arrow function
#
# ```js
# var/let/const functionName = (para1 , para2, ..... , paraN  , callBackFunction1, callBackFunction2, ....., callBackFunctionN ) => {
# 	//  function statement(s)
#     callBackFunction1(para1 , para2, ..... , paraN)
#     callBackFunction2(para1 , para2, ..... , paraN)
#       ....................................
#     callBackFunctionN(para1 , para2, ..... , paraN)
# }
# ```

# %% [markdown]
# ## Promises
#
# > * A Promise is in one of these states:
# >   * **pending**: initial state, neither fulfilled nor rejected.
# >   * **fulfilled**: meaning that the operation was completed successfully.
# >   * **rejected**: meaning that the operation failed.
#
# * The eventual state of a pending promise can either be fulfilled with a value or rejected with a reason (error). When either of these options occur, the associated handlers queued up by a promise's then method are called. If the promise has already been fulfilled or rejected when a corresponding handler is attached, the handler will be called, so there is no race condition between an asynchronous operation completing and its handlers being attached.
#
# A promise is said to be settled if it is either fulfilled or rejected, but not pending.
#
# ![promises_structure](./image/0018.JSPY.0005.javaScript_Python.function/promises_structure.png)
