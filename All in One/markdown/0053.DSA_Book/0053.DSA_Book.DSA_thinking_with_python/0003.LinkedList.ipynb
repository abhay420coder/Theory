# %% [markdown]
# # Linked List
# ## 3.1 what is a Linked List
# * A linked List is a data structure used for storing collections of data.
# * A linked list has the following properties.
#   * Successive elements a re connect.eel by pointers
#   * The last element points to NULL
#   * Can grow or shrink in size during execution of a program
#   * Can be made just as long as required (until systems memory exhausts)
#   * Docs not waste memory space (but takes some extra memory for pointers)
#   * `4 | ` ---> `15 | ` ---> `7 | ` ---> `40 | ` ---> `Null`
#   * `head`

# %% [markdown]
# ## 3.2 Linked Lists Operation
# * Create Linked List
# * Display/Print Linked Lists
# * Traversing Linked List
# * Insert element in LInked List
#   * Insert element at the begining
#   * Insert element at the ending
#   * Insert element between Nodes
# * Delete element from LInked List
#   * Delete element from the begining
#   * Delete element from the ending
#   * Delete element between Nodes
# * search element/Node in Linked lIst
# * Sort the Linked List
# * Merge two Linked List
# * Split a Linked List into two parts
# * Update Node/data in Lined List

# %% [markdown]
# ## 3.3 Why Linked Lists?
#
# * Both linked lists and arrays are used to
#   * store collections of data,
#   * and since both arc used for the same purpose,
#   * we need to differentiate their usage.
# * That means
#   * in which cases arrays are suitable
#   * and in which cases linked lists are suitable.

# %%
# node of a singly linked list


class Node:
    # constructor
    def __init__(self):
        self.data = None
        self.nextRef = None

    # method to set data in the node
    def setNodeData(self , data):
        self.data = data
    # method to get data in the node
    def getNodeData(self):
        return self.data
    
    # method to set/linked next-node in the node
    def setNextNode(self , nextNodeRef):
        self.nextRef = nextNodeRef
    # method to get next-node in the node
    def getNextNode(self):
        return self.nextRef
    
    # returns true if the node points to another-node
    def hasNextNode(self):
        return self.nextRef != None

# node1 = Node()
# node1.setNodeData(20)
# print("node1 :-" ,node1)
# print("node1.getNodeData() :-" ,node1.getNodeData())
# print("node1.getNodeData() :-" ,node1.getNodeData())

class LinkedList:
    def __init__(self):
        self.head = None
        
    def printLinkedList(self):
        n= self.head
        if n is None:
            print("we have an empty Linked Lists")
        else :
            while (n.nextRef is None):
                print("data is" , n.data);
                n = n.nextRef
        
    def insertAtBegining(self,data):
        new_Node = Node() # create a node
        new_Node.setNodeData(data) # set data to the node
        
        # if self.length == 0:
        #     self.head = new_Node
        # else :
        #     new_Node.setNextNode = self.head
        #     self.head = new_Node
        # self.length += 1
        
        

        new_Node.setNextNode(self.head)
        self.head = new_Node
        
# LL1 = LinkedList()
# LL1.insertAtBegining(20)
# LL1.printLinkedList()
# Out:
# node1 :- <__main__.Node object at 0x00000152049F6CE0>
# node1.getNodeData() :- 20
# node1.getNodeData() :- 20

# %%
class Node:
    def __init__(self , data):
        self.data = data
        self.ref = None
class LinkedList:
    def __init__(self):
        self.head = None # we can say head is starting_node_location of linked list
    
    
    def print_LL(self):
        if self.head is None:
            print("Linked List is empty")
        else:
            n = self.head
            while n is not None:
                print(n.data , end="-->")
                n = n.ref
                
                
    def insert_begin(self,data):
        new_node = Node(data) # create the node first
        new_node.ref = self.head # change new node reference to  head
        self.head = new_node # now head  will be updated with new_node location
        
    def insert_end(self, data):
        new_node = Node(data) # create the node first
        
        # firstly we will create a variable n 
        #  head(or head_location) will be stored in n
        n= self.head 
        
        # from below loop we will find last element of linked_list
        # we know that reference_of_last_element is None
        while(n.ref is not None): 
            n = n.ref
        n.ref = new_node
    
    def insert_after_the_Node(self, data , particularNodeData):
        new_node = Node(data) # create the node first
        
        # firstly we will create a variable n 
        #  head(or head_location) will be stored in n
        n = self.head 
        
        # from below loop we will find last element of linked_list
        # we know that reference_of_last_element is None
        while(n.data is not particularNodeData): 
            n = n.ref
        # n.ref = new_node
        
        print("getting node" , n.data)

        
LL1 = LinkedList()
LL1.insert_begin(10)
print()
print("check first time")
LL1.print_LL()
LL1.insert_begin(20)
LL1.insert_begin(30)
LL1.insert_begin(40)
LL1.insert_begin(50)
LL1.insert_begin(60)
LL1.insert_begin(70)
LL1.insert_begin(80)
print()
print("check second time")

LL1.print_LL()
print()
LL1.insert_end(110)
LL1.insert_end(120)
LL1.insert_end(130)
LL1.insert_end(140)
LL1.insert_end(150)

print()
print("check third time")

LL1.print_LL()
print()
# Out:
# check first time
# 10-->
# check second time
# 80-->70-->60-->50-->40-->30-->20-->10-->
#
# check third time
# 80-->70-->60-->50-->40-->30-->20-->10-->110-->120-->130-->140-->150-->

# %% [markdown]
# [12:09 PM] Arnab Ghosh
#
#
#
#
# bazaar.bh
#
# address picker-> change address if picker is changed (2 way binding) - Abhay
#
# logout-> ask confirmation - Abhay   -> modals -> tailwind ui compoent
#
# change picture- remove button - Abhay
#
# tab view , remove bottom border radius - Abhay
#
# nav bar address picker view -> Abhay
